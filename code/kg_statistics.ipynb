# %% [markdown]
# # EFFKG knowledge-graph statistics and validation
#
# This notebook queries the public EFFKG SPARQL endpoint and generates descriptive
# statistics and validation reports for the populated knowledge graph.
#
# The generated reports cover:
#
# - active and inactive vessel entities;
# - direct instances by class or category;
# - multilingual-label coverage;
# - category use;
# - statements and qualifiers by property;
# - statement-level references by source;
# - provenance coverage;
# - identifier uniqueness;
# - broken Wikibase-item links;
# - domain plausibility;
# - geospatial validity.
#
# All CSV reports are written to:
#
#     validation/kg_statistics/
#
# The notebook reads from the public SPARQL endpoint only. It does not modify
# Wikibase and does not require credentials.

# %% [markdown]
# # Setup

# %%
from pathlib import Path
from typing import Optional

import csv
import time

import requests

def find_repository_root(start: Optional[Path] = None) -> Path:
    """
    Locate the EFFKG repository root.

    The root is identified by the principal directories distributed with the
    project. This implementation is compatible with Python 3.9.
    """
    current = (start or Path.cwd()).resolve()

    required_directories = {
        "code",
        "dataset",
        "schema",
        "source_data",
        "data_model",
        "validation",
    }

    for candidate in [current] + list(current.parents):
        try:
            existing_directories = {
                path.name
                for path in candidate.iterdir()
                if path.is_dir()
            }
        except (PermissionError, OSError):
            continue

        if required_directories.issubset(existing_directories):
            return candidate

    raise RuntimeError(
        "The EFFKG repository root could not be located. "
        "Run this notebook from within a cloned EFFKG repository."
    )


REPOSITORY_ROOT = find_repository_root()

VALIDATION_DIRECTORY = REPOSITORY_ROOT / "validation"

OUTPUT_DIRECTORY = (
    VALIDATION_DIRECTORY
    / "kg_statistics"
)

OUTPUT_DIRECTORY.mkdir(
    parents=True,
    exist_ok=True
)


# -----------------------------------------------------------------------------
# Wikibase configuration
# -----------------------------------------------------------------------------

WIKIBASE_HOST = "effkg.wikibase.cloud"
WIKIBASE_URL = "https://{}".format(WIKIBASE_HOST)

SPARQL_ENDPOINT = (
    WIKIBASE_URL
    + "/query/sparql"
)

SOURCE_PROP = "P46"

HEADERS = {
    "Accept": "application/sparql-results+json",
    "User-Agent": (
        "EFFKG-KG-Statistics/1.0 "
        "(European Fishing Fleet Knowledge Graph)"
    ),
}

SESSION = requests.Session()
SESSION.headers.update(HEADERS)


# Backwards-compatible alias used in the existing SPARQL query templates.
ENDPOINT = "effkg"


def output_path(filename: str) -> Path:
    """
    Return the repository-relative path of a generated statistics report.
    """
    return OUTPUT_DIRECTORY / filename


print("EFFKG knowledge-graph statistics")
print("--------------------------------")
print("Repository root: {}".format(REPOSITORY_ROOT))
print("SPARQL endpoint: {}".format(SPARQL_ENDPOINT))
print("Output directory: {}".format(OUTPUT_DIRECTORY))
# Out:
# EFFKG knowledge-graph statistics
# --------------------------------
# Repository root: C:\Users\profesor\Documents\EFFKG
# SPARQL endpoint: https://effkg.wikibase.cloud/query/sparql
# Output directory: C:\Users\profesor\Documents\EFFKG\validation\kg_statistics

# %%
def run_query(query):
    """
    Execute a SPARQL query against the configured EFFKG endpoint.
    """
    response = SESSION.get(
        SPARQL_ENDPOINT,
        params={
            "query": query,
            "format": "json",
        },
        timeout=120,
    )

    response.raise_for_status()
    return response.json()

def run_query_timeout(
    query,
    timeout=120,
    max_retries=4,
    backoff_base=2,
):
    """
    Execute a SPARQL query with retry and exponential-backoff support.
    """
    last_error = None

    for attempt in range(1, max_retries + 1):
        try:
            response = SESSION.get(
                SPARQL_ENDPOINT,
                params={
                    "query": query,
                    "format": "json",
                },
                timeout=timeout,
            )

            if response.status_code >= 500:
                raise requests.HTTPError(
                    "HTTP {}: {}".format(
                        response.status_code,
                        response.text[:300],
                    ),
                    response=response,
                )

            response.raise_for_status()
            return response.json()

        except requests.RequestException as exc:
            last_error = exc

            if attempt == max_retries:
                break

            sleep_seconds = backoff_base ** (attempt - 1)

            print(
                "  attempt {}/{} failed: {}".format(
                    attempt,
                    max_retries,
                    exc,
                )
            )
            print(
                "  retrying in {}s...".format(
                    sleep_seconds
                )
            )

            time.sleep(sleep_seconds)

    raise last_error

# %% [markdown]
# # Summary statistics

# %% [markdown]
# ## Active vessel entities

# %%
INSTANCE_OF = "P35"
STATUS_PROPERTY = "P32"
RETIREMENT_DATE = "P57"
DESTRUCTION_DATE = "P58"

VESSEL_CLASSES = [
    "Q24",
    "Q398",
]

query = f"""
PREFIX wdt: <https://{ENDPOINT}.wikibase.cloud/prop/direct/>
PREFIX wd: <https://{ENDPOINT}.wikibase.cloud/entity/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT
  # ?vesselClassId
  # ?vesselClassLabel
  (COUNT(DISTINCT ?vessel) AS ?activeVessels)
WHERE {{
  VALUES ?vesselClass {{
    {" ".join("wd:" + qid for qid in VESSEL_CLASSES)}
  }}

  # ?vessel wdt:{INSTANCE_OF} ?vesselClass .

  FILTER NOT EXISTS {{
    # ?vessel wdt:{RETIREMENT_DATE} ?retirementDate .
  }}

  FILTER NOT EXISTS {{
    # ?vessel wdt:{DESTRUCTION_DATE} ?destructionDate .
  }}

  FILTER NOT EXISTS {{
    # ?vessel wdt:{STATUS_PROPERTY} "Baja Definitiva" .
  }}

  BIND(
    REPLACE(STR(?vesselClass), "^.*/entity/", "")
    AS ?vesselClassId
  )

  OPTIONAL {{
    # ?vesselClass rdfs:label ?vesselClassLabel .
    FILTER(LANG(?vesselClassLabel) = "en")
  }}
}}
GROUP BY ?vesselClassId ?vesselClassLabel
ORDER BY ?vesselClassId
"""

results = run_query(query)

rows = []

for binding in results["results"]["bindings"]:
    class_id = binding["vesselClassId"]["value"]

    class_label = binding.get(
        "vesselClassLabel",
        {},
    ).get("value", class_id)

    count = int(binding["activeVessels"]["value"])

    rows.append(
        (
            class_id,
            class_label,
            count,
        )
    )

total_active_class_memberships = sum(row[2] for row in rows)

print("\n=== ACTIVE VESSELS BY CLASS ===\n")

for class_id, class_label, count in rows:
    print(f"{class_id} | {class_label} | {count:,}")

print(
    f"\nTOTAL ACTIVE VESSEL CLASS MEMBERSHIPS: "
    f"{total_active_class_memberships:,}"
)
# Out:
# === ACTIVE VESSELS BY CLASS ===
#
# Q24 | Fishing Vessel | 69,897
# Q398 | Vessel supporting fishing related activities | 1,890
#
# TOTAL ACTIVE VESSEL CLASS MEMBERSHIPS: 71,787

# %% [markdown]
# ## Inactive vessel entities

# %%
query = f"""
PREFIX wdt: <https://{ENDPOINT}.wikibase.cloud/prop/direct/>
PREFIX wd: <https://{ENDPOINT}.wikibase.cloud/entity/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT
  # ?vesselClassId
  # ?vesselClassLabel
  (COUNT(DISTINCT ?vessel) AS ?inactiveVessels)
WHERE {{
  VALUES ?vesselClass {{
    {" ".join("wd:" + qid for qid in VESSEL_CLASSES)}
  }}

  # ?vessel wdt:{INSTANCE_OF} ?vesselClass .

  {{
    # ?vessel wdt:{RETIREMENT_DATE} ?retirementDate .
  }}
  UNION
  {{
    # ?vessel wdt:{DESTRUCTION_DATE} ?destructionDate .
  }}
  UNION
  {{
    # ?vessel wdt:{STATUS_PROPERTY} "Baja Definitiva" .
  }}

  BIND(
    REPLACE(STR(?vesselClass), "^.*/entity/", "")
    AS ?vesselClassId
  )

  OPTIONAL {{
    # ?vesselClass rdfs:label ?vesselClassLabel .
    FILTER(LANG(?vesselClassLabel) = "en")
  }}
}}
GROUP BY ?vesselClassId ?vesselClassLabel
ORDER BY ?vesselClassId
"""

results = run_query(query)

rows = []

for binding in results["results"]["bindings"]:
    class_id = binding["vesselClassId"]["value"]

    class_label = binding.get(
        "vesselClassLabel",
        {},
    ).get("value", class_id)

    count = int(binding["inactiveVessels"]["value"])

    rows.append(
        (
            class_id,
            class_label,
            count,
        )
    )

total_inactive_class_memberships = sum(row[2] for row in rows)

print("\n=== INACTIVE VESSELS BY CLASS ===\n")

for class_id, class_label, count in rows:
    print(f"{class_id} | {class_label} | {count:,}")

print(
    f"\nTOTAL INACTIVE VESSEL CLASS MEMBERSHIPS: "
    f"{total_inactive_class_memberships:,}"
)
# Out:
# === INACTIVE VESSELS BY CLASS ===
#
# Q24 | Fishing Vessel | 115,128
# Q398 | Vessel supporting fishing related activities | 1,255
#
# TOTAL INACTIVE VESSEL CLASS MEMBERSHIPS: 116,383

# %% [markdown]
# ## Items by type

# %%
INSTANCE_OF = "P35"
SUBCLASS_OF = "P52"

# -------------------------------------------------------------------
# Count direct instances of every entity used as an instance-of target
#
# This includes:
# - conventional classes connected through subclass of (P52);
# - category classes connected through instance of (P35);
# - root classes that do not have an explicitly modelled parent.
# -------------------------------------------------------------------

query = f"""
PREFIX wdt: <https://{ENDPOINT}.wikibase.cloud/prop/direct/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT
    # ?classId
    # ?classLabel
    # ?relation
    # ?parentId
    # ?parentLabel
    (COUNT(DISTINCT ?item) AS ?numberOfInstances)
WHERE {{
    # Any entity used as the object of P35 is treated as a class/category.
    # ?item wdt:{INSTANCE_OF} ?class .

    OPTIONAL {{
        {{
            # ?class wdt:{SUBCLASS_OF} ?parent .
            BIND("subclass of" AS ?relation)
        }}
        UNION
        {{
            # ?class wdt:{INSTANCE_OF} ?parent .
            BIND("instance of" AS ?relation)
        }}

        BIND(
            REPLACE(STR(?parent), "^.*/entity/", "")
            AS ?parentId
        )

        OPTIONAL {{
            # ?parent rdfs:label ?parentLabel .
            FILTER(LANG(?parentLabel) = "en")
        }}
    }}

    BIND(
        REPLACE(STR(?class), "^.*/entity/", "")
        AS ?classId
    )

    OPTIONAL {{
        # ?class rdfs:label ?classLabel .
        FILTER(LANG(?classLabel) = "en")
    }}
}}
GROUP BY
    # ?classId
    # ?classLabel
    # ?relation
    # ?parentId
    # ?parentLabel
ORDER BY DESC(?numberOfInstances) ?classId
"""

results = run_query(query)

# -------------------------------------------------------------------
# Parse results
# -------------------------------------------------------------------

rows = []

for binding in results["results"]["bindings"]:
    class_id = binding["classId"]["value"]

    class_label = binding.get(
        "classLabel",
        {},
    ).get("value", class_id)

    relation = binding.get(
        "relation",
        {},
    ).get("value", "")

    parent_id = binding.get(
        "parentId",
        {},
    ).get("value", "")

    parent_label = binding.get(
        "parentLabel",
        {},
    ).get("value", parent_id)

    count = int(binding["numberOfInstances"]["value"])

    rows.append(
        (
            class_id,
            class_label,
            relation,
            parent_id,
            parent_label,
            count,
        )
    )

# -------------------------------------------------------------------
# Sort descending
# -------------------------------------------------------------------

rows.sort(key=lambda row: row[5], reverse=True)

# -------------------------------------------------------------------
# Pretty-print results
# -------------------------------------------------------------------

def print_table(rows):
    headers = [
        "Class",
        "Class label",
        "Relation",
        "Parent",
        "Parent label",
        "Instances",
    ]

    table_rows = [
        [
            class_id,
            class_label,
            relation,
            parent_id,
            parent_label,
            f"{count:,}",
        ]
        for (
            class_id,
            class_label,
            relation,
            parent_id,
            parent_label,
            count,
        ) in rows
    ]

    all_rows = [headers] + table_rows

    col_widths = [
        max(len(str(row[i])) for row in all_rows)
        for i in range(len(headers))
    ]

    separator = "-+-".join(
        "-" * width
        for width in col_widths
    )

    print("\n=== ITEMS BY CLASS OR CATEGORY ===\n")

    print(
        " | ".join(
            headers[i].ljust(col_widths[i])
            for i in range(len(headers))
        )
    )

    print(separator)

    for row in table_rows:
        print(
            " | ".join(
                str(row[i]).ljust(col_widths[i])
                for i in range(len(headers))
            )
        )


print_table(rows)

# -------------------------------------------------------------------
# Totals
# -------------------------------------------------------------------

unique_classes = {
    row[0]
    for row in rows
}

# A class may occur in more than one row if it has multiple parents.
# Therefore, summing the rows may duplicate its instance count.
counts_by_class = {}

for row in rows:
    class_id = row[0]
    count = row[5]

    counts_by_class[class_id] = count

total_instance_relations = sum(counts_by_class.values())

print(f"\nUNIQUE CLASSES OR CATEGORIES: {len(unique_classes):,}")
print(f"TOTAL DIRECT INSTANCE RELATIONS: {total_instance_relations:,}")

# -------------------------------------------------------------------
# Export results to CSV
# -------------------------------------------------------------------

output_file = output_path(
    "items_by_class_or_category.csv"
)

with open(
    output_file,
    "w",
    newline="",
    encoding="utf-8-sig",
) as file:
    writer = csv.writer(file, delimiter=";")

    writer.writerow(
        [
            "Class",
            "ClassLabel",
            "HierarchyRelation",
            "Parent",
            "ParentLabel",
            "NumberOfDirectInstances",
        ]
    )

    writer.writerows(rows)

    writer.writerow([])
    writer.writerow(
        [
            "UNIQUE CLASSES OR CATEGORIES",
            len(unique_classes),
            "",
            "",
            "",
            "",
        ]
    )
    writer.writerow(
        [
            "TOTAL DIRECT INSTANCE RELATIONS",
            "",
            "",
            "",
            "",
            total_instance_relations,
        ]
    )

print(f"\nCSV exported: {output_file}")
# Out:
# === ITEMS BY CLASS OR CATEGORY ===
#
# Class  | Class label                                           | Relation    | Parent | Parent label                 | Instances
# -------+-------------------------------------------------------+-------------+--------+------------------------------+----------
# Q24    | Fishing Vessel                                        | subclass of | Q23    | Vessel                       | 185,025
# Q398   | Vessel supporting fishing related activities          | subclass of | Q23    | Vessel                       | 3,145
# Q62    | Fishing Port                                          | subclass of | Q488   | Port                         | 1,997
# Q13    | Fishing Area                                          | subclass of | Q28608 | Maritime administrative unit | 114
# Q138   | Maritime District                                     | subclass of | Q28608 | Maritime administrative unit | 108
# Q472   | Fishing Gear Category                                 | instance of | Q473   | Category                     | 71
# Q399   | Fishing Vessel Category                               | instance of | Q471   | Vessel Category              | 48
# Q63    | Maritime Province                                     | subclass of | Q28608 | Maritime administrative unit | 30
# Q448   | Vessel supporting fishing related activities Category | instance of | Q471   | Vessel Category              | 18
# Q28610 | Spanish Autonomous Community                          | subclass of | Q379   | Land administrative unit     | 17
# Q482   | Material                                              |             |        |                              | 9
# Q470   | On board Equipment                                    | subclass of | Q468   | Vessel Equipment             | 4
# Q471   | Vessel Category                                       | instance of | Q473   | Category                     | 2
# Q473   | Category                                              |             |        |                              | 2
# Q144   | Industrial Port                                       | subclass of | Q488   | Port                         | 1
#
# UNIQUE CLASSES OR CATEGORIES: 15
# TOTAL DIRECT INSTANCE RELATIONS: 190,591
#
# CSV exported: C:\Users\profesor\Documents\EFFKG\validation\kg_statistics\items_by_class_or_category.csv

# %% [markdown]
# ## Multilingual Labels

# %%
# ------------------------------------------------------------
# 1. Entities with labels in more than one language
# ------------------------------------------------------------

multilingual_entities_query = """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT (COUNT(*) AS ?multilingualEntities)
WHERE {
  {
    SELECT ?entity
    WHERE {
      # ?entity rdfs:label ?label .
      FILTER(LANG(?label) != "")
    }
    GROUP BY ?entity
    HAVING(COUNT(DISTINCT LANG(?label)) > 1)
  }
}
"""

multilingual_entities_results = run_query(
    multilingual_entities_query
)

multilingual_entities = int(
    multilingual_entities_results["results"]["bindings"][0]
    ["multilingualEntities"]["value"]
)


# ------------------------------------------------------------
# 2. Percentage
# ------------------------------------------------------------

total_entities = 190629 # As provided by Wikibase statistics
multilingual_percentage = (
    multilingual_entities / total_entities * 100
    if total_entities
    else 0
)

print(f"TOTAL ENTITIES: {total_entities:,}")
print(f"MULTILINGUAL ENTITIES: {multilingual_entities:,}")
print(
    f"MULTILINGUAL ENTITY COVERAGE: "
    f"{multilingual_percentage:.2f}%"
)
# Out:
# TOTAL ENTITIES: 190,629
# MULTILINGUAL ENTITIES: 190,579
# MULTILINGUAL ENTITY COVERAGE: 99.97%

# %% [markdown]
# ## Categories

# %%
INSTANCE_OF = "P35"
CATEGORY_OF = "P50"
CATEGORY_QID = "Q473"

ITEM_CATEGORY_PROPERTIES = [
    INSTANCE_OF,
    "P25",
]

query = f"""
PREFIX wdt: <https://{ENDPOINT}.wikibase.cloud/prop/direct/>
PREFIX wd: <https://{ENDPOINT}.wikibase.cloud/entity/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?categoryId ?categoryLabel
       # ?categoryOfId ?categoryOfLabel
       # ?subCategoryId ?subCategoryLabel
       (COUNT(DISTINCT ?item) AS ?numberOfItems)
WHERE {{
  # ?category wdt:{INSTANCE_OF} wd:{CATEGORY_QID} .

  OPTIONAL {{
    # ?category wdt:{CATEGORY_OF} ?categoryOf .
    BIND(REPLACE(STR(?categoryOf), "^.*/entity/", "") AS ?categoryOfId)

    OPTIONAL {{
      # ?categoryOf rdfs:label ?categoryOfLabel .
      FILTER(LANG(?categoryOfLabel) = "en")
    }}
  }}

  # ?subCategory wdt:{INSTANCE_OF} ?category .

  VALUES ?itemCategoryProperty {{
    {" ".join("wdt:" + p for p in ITEM_CATEGORY_PROPERTIES)}
  }}

  OPTIONAL {{
    # ?item ?itemCategoryProperty ?subCategory .
  }}

  BIND(REPLACE(STR(?category), "^.*/entity/", "") AS ?categoryId)
  BIND(REPLACE(STR(?subCategory), "^.*/entity/", "") AS ?subCategoryId)

  OPTIONAL {{
    # ?category rdfs:label ?categoryLabel .
    FILTER(LANG(?categoryLabel) = "en")
  }}

  OPTIONAL {{
    # ?subCategory rdfs:label ?subCategoryLabel .
    FILTER(LANG(?subCategoryLabel) = "en")
  }}
}}
GROUP BY ?categoryId ?categoryLabel ?categoryOfId ?categoryOfLabel ?subCategoryId ?subCategoryLabel
ORDER BY ?categoryLabel DESC(?numberOfItems)
"""

results = run_query(query)

rows = []

for b in results["results"]["bindings"]:
    category_id = b["categoryId"]["value"]
    category_label = b.get("categoryLabel", {}).get("value", category_id)

    category_of_id = b.get("categoryOfId", {}).get("value", "")
    category_of_label = b.get("categoryOfLabel", {}).get("value", category_of_id)

    subcategory_id = b["subCategoryId"]["value"]
    subcategory_label = b.get("subCategoryLabel", {}).get("value", subcategory_id)

    count = int(b["numberOfItems"]["value"])

    rows.append(
        (
            category_id,
            category_label,
            category_of_id,
            category_of_label,
            subcategory_id,
            subcategory_label,
            count,
        )
    )


def print_table(rows):
    headers = [
        "Category",
        "Category label",
        "Category of",
        "Category of label",
        "Subcategory",
        "Subcategory label",
        "Items",
    ]

    table_rows = [
        [
            category_id,
            category_label,
            category_of_id,
            category_of_label,
            subcategory_id,
            subcategory_label,
            f"{count:,}",
        ]
        for (
            category_id,
            category_label,
            category_of_id,
            category_of_label,
            subcategory_id,
            subcategory_label,
            count,
        ) in rows
    ]

    all_rows = [headers] + table_rows

    col_widths = [
        max(len(str(row[i])) for row in all_rows)
        for i in range(len(headers))
    ]

    separator = "-+-".join("-" * width for width in col_widths)

    print("\n=== CATEGORY ITEMS: SECOND LEVEL ===\n")
    print(" | ".join(headers[i].ljust(col_widths[i]) for i in range(len(headers))))
    print(separator)

    for row in table_rows:
        print(" | ".join(str(row[i]).ljust(col_widths[i]) for i in range(len(headers))))


print_table(rows)

total_subcategories = len(rows)
total_items = sum(row[6] for row in rows)

print(f"\nTOTAL SUBCATEGORIES: {total_subcategories:,}")
print(f"TOTAL ITEM RELATIONS: {total_items:,}")

with open(output_path("category_items_second_level.csv"), "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.writer(f, delimiter=";")

    writer.writerow(
        [
            "Category",
            "CategoryLabel",
            "CategoryOf",
            "CategoryOfLabel",
            "Subcategory",
            "SubcategoryLabel",
            "NumberOfItems",
        ]
    )

    writer.writerows(rows)

    writer.writerow([])
    writer.writerow(["TOTAL SUBCATEGORIES", total_subcategories, "", "", "", "", ""])
    writer.writerow(["TOTAL ITEM RELATIONS", "", "", "", "", "", total_items])

print("\nCSV exported: category_items_second_level.csv")
# Out:
# === CATEGORY ITEMS: SECOND LEVEL ===
#
# Category | Category label        | Category of | Category of label | Subcategory | Subcategory label                                              | Items
# ---------+-----------------------+-------------+-------------------+-------------+----------------------------------------------------------------+--------
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q511        | Set gillnets (anchored)                                        | 106,012
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q529        | Set longlines                                                  | 60,998
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q546        | Gear not known                                                 | 51,925
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q515        | Trammel nets                                                   | 39,274
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q520        | Pots                                                           | 27,036
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q485        | Single boat bottom otter trawls                                | 19,270
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q527        | Handlines and hand-operated pole-and-lines                     | 15,427
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q5          | Purse Seine                                                    | 9,473
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q497        | Towed dredges                                                  | 5,399
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q512        | Drift gillnets                                                 | 4,948
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q533        | Trolling lines                                                 | 4,435
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q530        | Drifting longlines                                             | 3,804
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q484        | Beam trawls                                                    | 3,477
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q491        | Single boat midwater otter trawls                              | 3,120
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q516        | Combined gillnets-trammel nets                                 | 2,691
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q544        | Gear NEI                                                       | 1,648
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q478        | Beach seines                                                   | 1,630
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q528        | Mechanized lines and pole-and-lines                            | 1,421
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q521        | Fyke nets                                                      | 1,328
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q489        | Bottom pair trawls                                             | 1,198
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q492        | Midwater pair trawls                                           | 1,163
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q498        | Hand dredges                                                   | 513
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q513        | Encircling gillnets                                            | 472
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q503        | Boat-operated lift nets                                        | 365
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q486        | Twin bottom otter trawls                                       | 217
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q525        | Traps (NEI)                                                    | 205
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q536        | Harpoons                                                       | 195
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q519        | Stationary uncovered pound nets                                | 146
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q537        | Hand implements (Wrenching gear, Clamps, Tongs, Rakes, Spears) | 94
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q531        | Longlines (NEI)                                                | 90
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q475        | Surrounding nets without purse lines                           | 84
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q543        | Diving                                                         | 75
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q499        | Mechanized dredges                                             | 66
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q479        | Boat seines                                                    | 63
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q480        | Seine nets (NEI)                                               | 57
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q532        | Vertical lines                                                 | 42
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q534        | Hooks and lines (NEI)                                          | 21
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q504        | Shore-operated stationary lift nets                            | 18
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q490        | Bottom trawls (NEI)                                            | 15
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q493        | Midwater trawls (NEI)                                          | 11
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q517        | Gillnets and entangling nets (NEI)                             | 9
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q495        | Trawls (NEI)                                                   | 7
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q514        | Fixed gillnets (on stakes)                                     | 7
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q476        | Surrounding nets (NEI)                                         | 5
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q522        | Stow nets                                                      | 5
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q487        | Multiple bottom otter trawls                                   | 3
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q505        | Lift nets (NEI)                                                | 3
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q523        | Barriers, fences, weirs, etc.                                  | 2
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q524        | Aerial traps                                                   | 1
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q541        | Scoopnets                                                      | 1
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q526        | Hooks and Lines                                                | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q535        | Miscellaneous Gear                                             | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q538        | Pumps                                                          | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q539        | Electric fishing                                               | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q540        | Pushnets                                                       | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q542        | Drive-in nets                                                  | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q545        | Gear Not Known                                                 | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q474        | Surrounding nets                                               | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q477        | Seine nets                                                     | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q483        | Trawls                                                         | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q494        | Semipelagic trawls                                             | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q496        | Dredges                                                        | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q500        | Dredges (NEI)                                                  | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q501        | Lift Nets                                                      | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q502        | Portable lift nets                                             | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q506        | Falling Gear                                                   | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q507        | Cast nets                                                      | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q508        | Cover pots/Lantern nets                                        | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q509        | Falling gear (NEI)                                             | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q510        | Gillnets and Entangling Nets                                   | 0
# Q472     | Fishing Gear Category | Q469        | Fishing Gear      | Q518        | Traps                                                          | 0
# Q471     | Vessel Category       | Q23         | Vessel            | Q399        | Fishing Vessel Category                                        | 48
# Q471     | Vessel Category       | Q23         | Vessel            | Q448        | Vessel supporting fishing related activities Category          | 18
#
# TOTAL SUBCATEGORIES: 73
# TOTAL ITEM RELATIONS: 368,535
#
# CSV exported: category_items_second_level.csv

# %% [markdown]
# # Statements by property

# %%
# Get all property IDs and labels
properties_query = """
PREFIX wikibase: <http://wikiba.se/ontology#>

SELECT ?propId ?propertyLabel
WHERE {
  # ?property a wikibase:Property ;
            wikibase:claim ?p ;
            rdfs:label ?propertyLabel .
  FILTER(LANG(?propertyLabel) = "en")
  BIND(REPLACE(STR(?property), "^.*/entity/", "") AS ?propId)
}
ORDER BY ?propId
"""

prop_results = run_query(properties_query)
properties = [
    (b["propId"]["value"], b["propertyLabel"]["value"])
    for b in prop_results["results"]["bindings"]
]

rows = []
total = 0

for prop_id, prop_label in properties:
    q = f"""
    PREFIX p: <https://{ENDPOINT}.wikibase.cloud/prop/>

    SELECT (COUNT(?statement) AS ?count)
    WHERE {{
      # ?item p:{prop_id} ?statement .
    }}
    """
    try:
        res = run_query(q)
        count = int(res["results"]["bindings"][0]["count"]["value"])
        if count > 0:
            rows.append((prop_id, prop_label, count))
            total += count
    except Exception as e:
        print(f"Error with {prop_id} ({prop_label}): {e}")

rows.sort(key=lambda x: x[2], reverse=True)

print("=== STATEMENTS BY PROPERTY ===")
for prop_id, prop_label, count in rows:
    print(f"{prop_id}\t{prop_label}\t{count}")

print(f"\nTOTAL STATEMENTS: {total}")

with open(output_path("statements_by_property.csv"), "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.writer(f, delimiter=";")
    writer.writerow(["Property", "Label", "NumberOfStatements"])
    writer.writerows(rows)
    writer.writerow([])
    writer.writerow(["TOTAL", "", total])
# Out:
# === STATEMENTS BY PROPERTY ===
# P25	has fishing gear category	371013
# P23	main engine power	213317
# P35	instance of	190592
# P12	CFR	188177
# P51	has vessel category	187575
# P55	country of registration	185685
# P9	external marking	185617
# P59	segment	184804
# P10	registration number	183401
# P29	entry into service date	183396
# P37	name	182619
# P16	LOA	181359
# P27	hull material	175595
# P30	date of construction	160307
# P20	GT Tonnage	153629
# P21	other tonnage	126242
# P11	registration place	124760
# P28	on board equipment	115614
# P17	LBP	77697
# P58	date of retirement	71896
# P57	date of destruction	42551
# P26	code	32992
# P32	status on national registry	30730
# P49	IMO	30529
# P31	registration on national registry	30527
# P56	administration responsible of registration	30527
# P41	operates at	23829
# P15	MMSI	20309
# P24	auxiliar engine power	9499
# P45	number of vessels	5177
# P14	UVI	3868
# P42	coordinates	1927
# P3	belongs to administrative unit	430
# P22	safety tonnage GTs	338
# P7	has ports	295
# P60	administrated by	155
# P43	contains administrative unit	136
# P53	abbreviation	126
# P18	has parent category	107
# P36	division of	92
# P39	has divisions	92
# P5	plate name	31
# P6	flag	29
# P38	subarea of	21
# P40	has subareas	19
# P52	subclass of	13
# P50	category of	4
# P1	defined by	3
# P54	superseded by	3
# P19	Wikidata reference	2
#
# TOTAL STATEMENTS: 3707656

# %% [markdown]
# # Qualifiers by property

# %%
# Retrieve properties that can act as qualifiers
qualifier_props_query = """
PREFIX wikibase: <http://wikiba.se/ontology#>

SELECT ?propId ?propertyLabel
WHERE {
  # ?property a wikibase:Property ;
            wikibase:qualifier ?pqProp ;
            rdfs:label ?propertyLabel .
  FILTER(LANG(?propertyLabel) = "en")
  BIND(REPLACE(STR(?property), "^.*/entity/", "") AS ?propId)
}
ORDER BY ?propId
"""

results = run_query(qualifier_props_query)
props = [
    (b["propId"]["value"], b["propertyLabel"]["value"])
    for b in results["results"]["bindings"]
]

rows = []
total = 0

for prop_id, prop_label in props:
    q = f"""
    PREFIX pq: <https://{ENDPOINT}.wikibase.cloud/prop/qualifier/>

    SELECT (COUNT(DISTINCT ?statement) AS ?count)
    WHERE {{
      # ?statement pq:{prop_id} ?value .
    }}
    """
    try:
        res = run_query(q)
        count = int(res["results"]["bindings"][0]["count"]["value"])
        if count > 0:
            rows.append((prop_id, prop_label, count))
            total += count
            print(f"{prop_id}\t{prop_label}\t{count}")
    except Exception as e:
        print(f"Error with {prop_id} ({prop_label}): {e}")

rows.sort(key=lambda x: x[2], reverse=True)

print("\n=== QUALIFIERS BY PROPERTY ===")
for prop_id, prop_label, count in rows:
    print(f"{prop_id}\t{prop_label}\t{count}")

print(f"\nTOTAL QUALIFIED STATEMENTS COUNTED: {total}")

qualifiers_output_file = output_path(
    "qualifiers_by_property.csv"
)

with qualifiers_output_file.open(
    "w",
    newline="",
    encoding="utf-8-sig",
) as file:
    writer = csv.writer(
        file,
        delimiter=";",
    )

    writer.writerow(
        [
            "Property",
            "Label",
            "NumberOfQualifiedStatements",
        ]
    )

    writer.writerows(rows)

    writer.writerow([])
    writer.writerow(
        [
            "TOTAL",
            "",
            total,
        ]
    )

print(
    "\nCSV exported: {}".format(
        qualifiers_output_file
    )
)
# Out:
# P13	IRCS	52858
# P32	status on national registry	3
# P33	since	30730
# P44	date	5180
# P47	start date	129
# P48	end date	57
# P55	country of registration	12682
#
# === QUALIFIERS BY PROPERTY ===
# P13	IRCS	52858
# P33	since	30730
# P55	country of registration	12682
# P44	date	5180
# P47	start date	129
# P48	end date	57
# P32	status on national registry	3
#
# TOTAL QUALIFIED STATEMENTS COUNTED: 101639
#
# CSV exported: C:\Users\profesor\Documents\EFFKG\validation\kg_statistics\qualifiers_by_property.csv

# %% [markdown]
# # References by source value

# %%
SOURCES = [
    "https://webgate.ec.europa.eu/fleet-europa",
    "https://servicio.pesca.mapama.es/CENSO/ConsultaBuqueRegistro/Buques/Search",
    "https://signa.ign.es/signa/",
    "https://www.mapa.gob.es/es/pesca/temas/registro-flota/informacion-sobre-flota-pesquera",
    "https://openknowledge.fao.org/handle/20.500.14283/cb5201en",
    "https://data.apps.fao.org/catalog/dataset/cwp-isscfg",
    "https://msi.nga.mil/Publications/WPI",
    "https://www.data.gouv.fr/datasets/liste-des-ports-du-systeme-ers-avec-donnees-de-position",
    "https://www.fao.org/fishery/en/area",
    "https://www.boe.es/eli/es/rd/2007/05/18/638/con",
]

"""Count statements referencing a specific source URL."""
def count_statements_for_source(source_url):
    query = f"""
    PREFIX prov: <http://www.w3.org/ns/prov#>
    PREFIX pr: <https://{ENDPOINT}.wikibase.cloud/prop/reference/>

    SELECT (COUNT(DISTINCT ?statement) AS ?count)
    WHERE {{
      # ?statement prov:wasDerivedFrom ?reference .
      # ?reference pr:{SOURCE_PROP} <{source_url}> .
    }}
    """

    result = run_query_timeout(query)
    bindings = result.get("results", {}).get("bindings", [])
    if not bindings:
        return 0

    return int(bindings[0]["count"]["value"])

"""Generate statistics for statements grouped by reference source."""
def main():
    rows = []
    total = 0

    print("=== REFERENCES BY SOURCE VALUE ===")

    for idx, source in enumerate(SOURCES, start=1):
        print(f"[{idx}/{len(SOURCES)}] {source}")

        try:
            count = count_statements_for_source(source)
            rows.append({
                "source": source,
                "numberOfStatements": count,
                "status": "OK",
                "error": ""
            })
            total += count
            print(f"  -> {count}")

        except Exception as e:
            rows.append({
                "source": source,
                "numberOfStatements": "",
                "status": "ERROR",
                "error": str(e)
            })
            print(f"  -> ERROR: {e}")

        time.sleep(1)

    print(f"\nTOTAL REFERENCED STATEMENTS: {total}")

    rows_sorted = sorted(
        rows,
        key=lambda r: r["numberOfStatements"] if isinstance(r["numberOfStatements"], int) else -1,
        reverse=True
    )

    with open(output_path("references_by_source.csv"), "w", newline="", encoding="utf-8-sig") as f:
        writer = csv.writer(f, delimiter=";")
        writer.writerow(["source", "numberOfStatements", "status", "error"])

        for row in rows_sorted:
            writer.writerow([
                row["source"],
                row["numberOfStatements"],
                row["status"],
                row["error"]
            ])

        writer.writerow([])
        writer.writerow(["TOTAL", total, "", ""])

    print("\nCSV generated: references_by_source.csv")

if __name__ == "__main__":
    main()
# Out:
# === REFERENCES BY SOURCE VALUE ===
# [1/10] https://webgate.ec.europa.eu/fleet-europa
#   -> 3448294
# [2/10] https://servicio.pesca.mapama.es/CENSO/ConsultaBuqueRegistro/Buques/Search
#   -> 570603
# [3/10] https://signa.ign.es/signa/
#   -> 193
# [4/10] https://www.mapa.gob.es/es/pesca/temas/registro-flota/informacion-sobre-flota-pesquera
#   -> 5158
# [5/10] https://openknowledge.fao.org/handle/20.500.14283/cb5201en
#   -> 244
# [6/10] https://data.apps.fao.org/catalog/dataset/cwp-isscfg
#   -> 321
# [7/10] https://msi.nga.mil/Publications/WPI
#   -> 999
# [8/10] https://www.data.gouv.fr/datasets/liste-des-ports-du-systeme-ers-avec-donnees-de-position
#   -> 6313
# [9/10] https://www.fao.org/fishery/en/area
#   -> 569
# [10/10] https://www.boe.es/eli/es/rd/2007/05/18/638/con
#   -> 1151
#
# TOTAL REFERENCED STATEMENTS: 4033845
#
# CSV generated: references_by_source.csv

# %% [markdown]
# # Provenance coverage

# %%
# Get all properties with claims

properties_query = """
PREFIX wikibase: <http://wikiba.se/ontology#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?propId ?propertyLabel
WHERE {
  # ?property a wikibase:Property ;
            wikibase:claim ?claimProp .

  OPTIONAL {
    # ?property rdfs:label ?propertyLabel .
    FILTER(LANG(?propertyLabel) = "en")
  }

  BIND(REPLACE(STR(?property), "^.*/entity/", "") AS ?propId)
}
ORDER BY ?propId
"""

prop_results = run_query(properties_query)

properties = [
    (
        b["propId"]["value"],
        b.get("propertyLabel", {}).get("value", b["propId"]["value"])
    )
    for b in prop_results["results"]["bindings"]
]

rows = []
total_statements = 0
total_statements_with_reference = 0

print("\n=== PROVENANCE COVERAGE BY PROPERTY ===\n")

for idx, (prop_id, prop_label) in enumerate(properties, start=1):
    print(f"[{idx}/{len(properties)}] {prop_id} {prop_label}")

    query = f"""
    PREFIX p: <https://{ENDPOINT}.wikibase.cloud/prop/>
    PREFIX prov: <http://www.w3.org/ns/prov#>

    SELECT ?totalStatements ?statementsWithReference
    WHERE {{
      {{
        SELECT (COUNT(?statement) AS ?totalStatements)
        WHERE {{
          # ?entity p:{prop_id} ?statement .
        }}
      }}

      {{
        SELECT (COUNT(DISTINCT ?statement) AS ?statementsWithReference)
        WHERE {{
          # ?entity p:{prop_id} ?statement .
          # ?statement prov:wasDerivedFrom ?reference .
        }}
      }}
    }}
    """

    try:
        results = run_query_timeout(query)
        b = results["results"]["bindings"][0]

        property_total = int(b["totalStatements"]["value"])
        property_with_reference = int(b["statementsWithReference"]["value"])
        property_without_reference = property_total - property_with_reference

        property_percent_with_reference = (
            property_with_reference / property_total * 100
            if property_total else 0
        )

        if property_total > 0:
            rows.append((
                prop_id,
                prop_label,
                property_total,
                property_with_reference,
                property_without_reference,
                property_percent_with_reference,
            ))

            total_statements += property_total
            total_statements_with_reference += property_with_reference

        print(
            f"  -> total={property_total:,}; "
            f"with reference={property_with_reference:,}; "
            f"without reference={property_without_reference:,}; "
            f"coverage={property_percent_with_reference:.3f}%"
        )

    except Exception as e:
        print(f"  -> ERROR: {e}")
        rows.append((prop_id, prop_label, "", "", "", ""))

    time.sleep(0.5)

total_statements_without_reference = (
    total_statements - total_statements_with_reference
)

percent_with_reference = (
    total_statements_with_reference / total_statements * 100
    if total_statements else 0
)

rows_valid = [r for r in rows if r[2] != ""]
rows_valid.sort(key=lambda x: x[5])

print("\n=== PROVENANCE COVERAGE ===\n")
print("Total statements | Statements with reference | Statements without reference | % with reference")
print("-----------------+---------------------------+------------------------------+-----------------")
print(
    f"{total_statements:,} | "
    f"{total_statements_with_reference:,} | "
    f"{total_statements_without_reference:,} | "
    f"{percent_with_reference:.3f}"
)

print("\n=== PROVENANCE COVERAGE BY PROPERTY ===\n")
print("Property | Label | Total | With reference | Without reference | % with reference")
print("---------+-------+-------+----------------+-------------------+-----------------")

for prop_id, prop_label, prop_total, prop_with_ref, prop_without_ref, prop_percent in rows_valid:
    print(
        f"{prop_id}\t{prop_label}\t{prop_total:,}\t"
        f"{prop_with_ref:,}\t{prop_without_ref:,}\t{prop_percent:.3f}"
    )

with open(output_path("provenance_coverage.csv"), "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.writer(f, delimiter=";")
    writer.writerow([
        "TotalStatements",
        "StatementsWithReference",
        "StatementsWithoutReference",
        "PercentWithReference"
    ])
    writer.writerow([
        total_statements,
        total_statements_with_reference,
        total_statements_without_reference,
        percent_with_reference
    ])

with open(output_path("provenance_coverage_by_property.csv"), "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.writer(f, delimiter=";")
    writer.writerow([
        "Property",
        "PropertyLabel",
        "TotalStatements",
        "StatementsWithReference",
        "StatementsWithoutReference",
        "PercentWithReference"
    ])
    writer.writerows(rows_valid)

print("\nCSV exported: provenance_coverage.csv")
print("CSV exported: provenance_coverage_by_property.csv")
# Out:
# === PROVENANCE COVERAGE BY PROPERTY ===
#
# [1/60] P1 defined by
#   -> total=3; with reference=3; without reference=0; coverage=100.000%
# [2/60] P10 registration number
#   -> total=183,401; with reference=183,401; without reference=0; coverage=100.000%
# [3/60] P11 registration place
#   -> total=124,760; with reference=124,760; without reference=0; coverage=100.000%
# [4/60] P12 CFR
#   -> total=188,177; with reference=188,177; without reference=0; coverage=100.000%
# [5/60] P13 IRCS
#   -> total=0; with reference=0; without reference=0; coverage=0.000%
# [6/60] P14 UVI
#   -> total=3,868; with reference=3,868; without reference=0; coverage=100.000%
# [7/60] P15 MMSI
#   -> total=20,309; with reference=20,309; without reference=0; coverage=100.000%
# [8/60] P16 LOA
#   -> total=181,359; with reference=181,359; without reference=0; coverage=100.000%
# [9/60] P17 LBP
#   -> total=77,697; with reference=77,697; without reference=0; coverage=100.000%
# [10/60] P18 has parent category
#   -> total=107; with reference=107; without reference=0; coverage=100.000%
# [11/60] P19 Wikidata reference
#   -> total=2; with reference=0; without reference=2; coverage=0.000%
# [12/60] P2 ID
#   -> total=0; with reference=0; without reference=0; coverage=0.000%
# [13/60] P20 GT Tonnage
#   -> total=153,629; with reference=153,629; without reference=0; coverage=100.000%
# [14/60] P21 other tonnage
#   -> total=126,242; with reference=126,242; without reference=0; coverage=100.000%
# [15/60] P22 safety tonnage GTs
#   -> total=338; with reference=338; without reference=0; coverage=100.000%
# [16/60] P23 main engine power
#   -> total=213,317; with reference=213,315; without reference=2; coverage=99.999%
# [17/60] P24 auxiliar engine power
#   -> total=9,499; with reference=9,499; without reference=0; coverage=100.000%
# [18/60] P25 has fishing gear category
#   -> total=371,013; with reference=371,013; without reference=0; coverage=100.000%
# [19/60] P26 code
#   -> total=32,992; with reference=32,989; without reference=3; coverage=99.991%
# [20/60] P27 hull material
#   -> total=175,595; with reference=175,595; without reference=0; coverage=100.000%
# [21/60] P28 on board equipment
#   -> total=115,614; with reference=115,614; without reference=0; coverage=100.000%
# [22/60] P29 entry into service date
#   -> total=183,396; with reference=183,394; without reference=2; coverage=99.999%
# [23/60] P3 belongs to administrative unit
#   -> total=430; with reference=429; without reference=1; coverage=99.767%
# [24/60] P30 date of construction
#   -> total=160,307; with reference=160,307; without reference=0; coverage=100.000%
# [25/60] P31 registration on national registry
#   -> total=30,527; with reference=30,527; without reference=0; coverage=100.000%
# [26/60] P32 status on national registry
#   -> total=30,730; with reference=30,730; without reference=0; coverage=100.000%
# [27/60] P33 since
#   -> total=0; with reference=0; without reference=0; coverage=0.000%
# [28/60] P34 image
#   -> total=0; with reference=0; without reference=0; coverage=0.000%
# [29/60] P35 instance of
#   -> total=190,592; with reference=190,544; without reference=48; coverage=99.975%
# [30/60] P36 division of
#   -> total=92; with reference=91; without reference=1; coverage=98.913%
# [31/60] P37 name
#   -> total=182,619; with reference=182,617; without reference=2; coverage=99.999%
# [32/60] P38 subarea of
#   -> total=21; with reference=21; without reference=0; coverage=100.000%
# [33/60] P39 has divisions
#   -> total=92; with reference=92; without reference=0; coverage=100.000%
# [34/60] P4 has delimitation
#   -> total=0; with reference=0; without reference=0; coverage=0.000%
# [35/60] P40 has subareas
#   -> total=19; with reference=19; without reference=0; coverage=100.000%
# [36/60] P41 operates at
#   -> total=23,829; with reference=23,829; without reference=0; coverage=100.000%
# [37/60] P42 coordinates
#   -> total=1,927; with reference=1,631; without reference=296; coverage=84.639%
# [38/60] P43 contains administrative unit
#   -> total=136; with reference=108; without reference=28; coverage=79.412%
# [39/60] P44 date
#   -> total=0; with reference=0; without reference=0; coverage=0.000%
# [40/60] P45 number of vessels
#   -> total=5,177; with reference=5,158; without reference=19; coverage=99.633%
# [41/60] P46 source
#   -> total=0; with reference=0; without reference=0; coverage=0.000%
# [42/60] P47 start date
#   -> total=0; with reference=0; without reference=0; coverage=0.000%
# [43/60] P48 end date
#   -> total=0; with reference=0; without reference=0; coverage=0.000%
# [44/60] P49 IMO
#   -> total=30,529; with reference=30,529; without reference=0; coverage=100.000%
# [45/60] P5 plate name
#   -> total=31; with reference=31; without reference=0; coverage=100.000%
# [46/60] P50 category of
#   -> total=4; with reference=0; without reference=4; coverage=0.000%
# [47/60] P51 has vessel category
#   -> total=187,575; with reference=187,572; without reference=3; coverage=99.998%
# [48/60] P52 subclass of
#   -> total=13; with reference=0; without reference=13; coverage=0.000%
# [49/60] P53 abbreviation
#   -> total=126; with reference=126; without reference=0; coverage=100.000%
# [50/60] P54 superseded by
#   -> total=3; with reference=3; without reference=0; coverage=100.000%
# [51/60] P55 country of registration
#   -> total=185,685; with reference=185,685; without reference=0; coverage=100.000%
# [52/60] P56 administration responsible of registration
#   -> total=30,527; with reference=30,526; without reference=1; coverage=99.997%
# [53/60] P57 date of destruction
#   -> total=42,551; with reference=42,551; without reference=0; coverage=100.000%
# [54/60] P58 date of retirement
#   -> total=71,896; with reference=71,895; without reference=1; coverage=99.999%
# [55/60] P59 segment
#   -> total=184,804; with reference=184,804; without reference=0; coverage=100.000%
# [56/60] P6 flag
#   -> total=29; with reference=29; without reference=0; coverage=100.000%
# [57/60] P60 administrated by
#   -> total=155; with reference=155; without reference=0; coverage=100.000%
# [58/60] P7 has ports
#   -> total=295; with reference=295; without reference=0; coverage=100.000%
# [59/60] P8 has demarcation
#   -> total=0; with reference=0; without reference=0; coverage=0.000%
# [60/60] P9 external marking
#   -> total=185,617; with reference=185,617; without reference=0; coverage=100.000%
#
# === PROVENANCE COVERAGE ===
#
# Total statements | Statements with reference | Statements without reference | % with reference
# -----------------+---------------------------+------------------------------+-----------------
# 3,707,656 | 3,707,230 | 426 | 99.989
#
# === PROVENANCE COVERAGE BY PROPERTY ===
#
# Property | Label | Total | With reference | Without reference | % with reference
# ---------+-------+-------+----------------+-------------------+-----------------
# P19	Wikidata reference	2	0	2	0.000
# P50	category of	4	0	4	0.000
# P52	subclass of	13	0	13	0.000
# P43	contains administrative unit	136	108	28	79.412
# P42	coordinates	1,927	1,631	296	84.639
# P36	division of	92	91	1	98.913
# P45	number of vessels	5,177	5,158	19	99.633
# P3	belongs to administrative unit	430	429	1	99.767
# P35	instance of	190,592	190,544	48	99.975
# P26	code	32,992	32,989	3	99.991
# P56	administration responsible of registration	30,527	30,526	1	99.997
# P51	has vessel category	187,575	187,572	3	99.998
# P58	date of retirement	71,896	71,895	1	99.999
# P37	name	182,619	182,617	2	99.999
# P29	entry into service date	183,396	183,394	2	99.999
# P23	main engine power	213,317	213,315	2	99.999
# P1	defined by	3	3	0	100.000
# P10	registration number	183,401	183,401	0	100.000
# P11	registration place	124,760	124,760	0	100.000
# P12	CFR	188,177	188,177	0	100.000
# P14	UVI	3,868	3,868	0	100.000
# P15	MMSI	20,309	20,309	0	100.000
# P16	LOA	181,359	181,359	0	100.000
# P17	LBP	77,697	77,697	0	100.000
# P18	has parent category	107	107	0	100.000
# P20	GT Tonnage	153,629	153,629	0	100.000
# P21	other tonnage	126,242	126,242	0	100.000
# P22	safety tonnage GTs	338	338	0	100.000
# P24	auxiliar engine power	9,499	9,499	0	100.000
# P25	has fishing gear category	371,013	371,013	0	100.000
# P27	hull material	175,595	175,595	0	100.000
# P28	on board equipment	115,614	115,614	0	100.000
# P30	date of construction	160,307	160,307	0	100.000
# P31	registration on national registry	30,527	30,527	0	100.000
# P32	status on national registry	30,730	30,730	0	100.000
# P38	subarea of	21	21	0	100.000
# P39	has divisions	92	92	0	100.000
# P40	has subareas	19	19	0	100.000
# P41	operates at	23,829	23,829	0	100.000
# P49	IMO	30,529	30,529	0	100.000
# P5	plate name	31	31	0	100.000
# P53	abbreviation	126	126	0	100.000
# P54	superseded by	3	3	0	100.000
# P55	country of registration	185,685	185,685	0	100.000
# P57	date of destruction	42,551	42,551	0	100.000
# P59	segment	184,804	184,804	0	100.000
# P6	flag	29	29	0	100.000
# P60	administrated by	155	155	0	100.000
# P7	has ports	295	295	0	100.000
# P9	external marking	185,617	185,617	0	100.000
#
# CSV exported: provenance_coverage.csv
# CSV exported: provenance_coverage_by_property.csv

# %% [markdown]
# # Identifier uniqueness validation

# %%
IDENTIFIER_PROPERTIES = [
    ("CFR", "P12"),
    ("IMO", "P49"),
    ("UVI", "P14"),
    ("MMSI", "P15"),
    ("Registration number", "P10"),
    ("External marking", "P9"),
]

PLACEHOLDER_VALUE = "-"

rows = []

for identifier_label, prop_id in IDENTIFIER_PROPERTIES:

    query = f"""
    PREFIX wdt: <https://{ENDPOINT}.wikibase.cloud/prop/direct/>

    SELECT ?sourceLevelEntities ?sourceLevelValues
           # ?sourceLevelDuplicatedValues ?sourceLevelAffectedEntities
           # ?placeholderFilteredEntities ?placeholderFilteredValues
           # ?placeholderFilteredDuplicatedValues ?placeholderFilteredAffectedEntities
           (((?sourceLevelValues - ?sourceLevelDuplicatedValues) / ?sourceLevelValues) * 100 AS ?sourceLevelValueUniquenessRate)
           (((?sourceLevelEntities - ?sourceLevelAffectedEntities) / ?sourceLevelEntities) * 100 AS ?sourceLevelEntityUniquenessRate)
           (((?placeholderFilteredValues - ?placeholderFilteredDuplicatedValues) / ?placeholderFilteredValues) * 100 AS ?placeholderFilteredValueUniquenessRate)
           (((?placeholderFilteredEntities - ?placeholderFilteredAffectedEntities) / ?placeholderFilteredEntities) * 100 AS ?placeholderFilteredEntityUniquenessRate)
    WHERE {{
      {{
        SELECT
          (COUNT(?entity) AS ?sourceLevelEntities)
          (COUNT(DISTINCT ?id) AS ?sourceLevelValues)
        WHERE {{
          # ?entity wdt:{prop_id} ?id .
        }}
      }}

      {{
        SELECT
          (COUNT(?id) AS ?sourceLevelDuplicatedValues)
          (SUM(?nEntities) AS ?sourceLevelAffectedEntities)
        WHERE {{
          {{
            SELECT ?id (COUNT(DISTINCT ?entity) AS ?nEntities)
            WHERE {{
              # ?entity wdt:{prop_id} ?id .
            }}
            GROUP BY ?id
            HAVING (COUNT(DISTINCT ?entity) > 1)
          }}
        }}
      }}

      {{
        SELECT
          (COUNT(?entity) AS ?placeholderFilteredEntities)
          (COUNT(DISTINCT ?id) AS ?placeholderFilteredValues)
        WHERE {{
          # ?entity wdt:{prop_id} ?id .
          FILTER(STR(?id) != "{PLACEHOLDER_VALUE}")
        }}
      }}

      {{
        SELECT
          (COUNT(?id) AS ?placeholderFilteredDuplicatedValues)
          (SUM(?nEntities) AS ?placeholderFilteredAffectedEntities)
        WHERE {{
          {{
            SELECT ?id (COUNT(DISTINCT ?entity) AS ?nEntities)
            WHERE {{
              # ?entity wdt:{prop_id} ?id .
              FILTER(STR(?id) != "{PLACEHOLDER_VALUE}")
            }}
            GROUP BY ?id
            HAVING (COUNT(DISTINCT ?entity) > 1)
          }}
        }}
      }}
    }}
    """

    try:
        results = run_query(query)
        b = results["results"]["bindings"][0]

        rows.append((
            identifier_label,
            prop_id,

            int(b["sourceLevelEntities"]["value"]),
            int(b["sourceLevelValues"]["value"]),
            int(b["sourceLevelDuplicatedValues"]["value"]),
            int(b["sourceLevelAffectedEntities"]["value"]),
            float(b["sourceLevelValueUniquenessRate"]["value"]),
            float(b["sourceLevelEntityUniquenessRate"]["value"]),

            int(b["placeholderFilteredEntities"]["value"]),
            int(b["placeholderFilteredValues"]["value"]),
            int(b["placeholderFilteredDuplicatedValues"]["value"]),
            int(b["placeholderFilteredAffectedEntities"]["value"]),
            float(b["placeholderFilteredValueUniquenessRate"]["value"]),
            float(b["placeholderFilteredEntityUniquenessRate"]["value"]),
        ))

    except Exception as e:
        print(f"Error with {identifier_label} ({prop_id}): {e}")
        rows.append((
            identifier_label, prop_id,
            "", "", "", "", "", "",
            "", "", "", "", "", ""
        ))

print("\n=== IDENTIFIER UNIQUENESS VALIDATION ===\n")
print(
    "Identifier | Property | "
    "Source-level entities | Source-level values | Source-level duplicated values | "
    "Source-level affected entities | Source-level entity uniqueness % | "
    "Placeholder-filtered entities | Placeholder-filtered values | "
    "Placeholder-filtered duplicated values | Placeholder-filtered affected entities | "
    "Placeholder-filtered entity uniqueness %"
)
print(
    "-----------+----------+-----------------------+---------------------+-------------------------------+"
    "-------------------------------+----------------------------------+-------------------------------+"
    "-----------------------------+---------------------------------------+--------------------------------------+"
    "------------------------------------------"
)

for (
    identifier_label,
    prop_id,

    source_level_entities,
    source_level_values,
    source_level_duplicated_values,
    source_level_affected_entities,
    source_level_value_uniqueness_rate,
    source_level_entity_uniqueness_rate,

    placeholder_filtered_entities,
    placeholder_filtered_values,
    placeholder_filtered_duplicated_values,
    placeholder_filtered_affected_entities,
    placeholder_filtered_value_uniqueness_rate,
    placeholder_filtered_entity_uniqueness_rate,
) in rows:

    if source_level_entities == "":
        print(f"{identifier_label}\t{prop_id}\tERROR")
    else:
        print(
            f"{identifier_label}\t{prop_id}\t"
            f"{source_level_entities:,}\t"
            f"{source_level_values:,}\t"
            f"{source_level_duplicated_values:,}\t"
            f"{source_level_affected_entities:,}\t"
            f"{source_level_entity_uniqueness_rate:.3f}\t"
            f"{placeholder_filtered_entities:,}\t"
            f"{placeholder_filtered_values:,}\t"
            f"{placeholder_filtered_duplicated_values:,}\t"
            f"{placeholder_filtered_affected_entities:,}\t"
            f"{placeholder_filtered_entity_uniqueness_rate:.3f}"
        )

with open(output_path("identifier_uniqueness.csv"), "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.writer(f, delimiter=";")
    writer.writerow([
        "Identifier",
        "Property",

        "SourceLevelEntitiesWithIdentifier",
        "SourceLevelDistinctValues",
        "SourceLevelDuplicatedValues",
        "SourceLevelAffectedEntities",
        "SourceLevelValueUniquenessRate",
        "SourceLevelEntityUniquenessRate",

        "PlaceholderFilteredEntitiesWithIdentifier",
        "PlaceholderFilteredDistinctValues",
        "PlaceholderFilteredDuplicatedValues",
        "PlaceholderFilteredAffectedEntities",
        "PlaceholderFilteredValueUniquenessRate",
        "PlaceholderFilteredEntityUniquenessRate"
    ])
    writer.writerows(rows)

print("\nCSV exported: identifier_uniqueness.csv")
# Out:
# === IDENTIFIER UNIQUENESS VALIDATION ===
#
# Identifier | Property | Source-level entities | Source-level values | Source-level duplicated values | Source-level affected entities | Source-level entity uniqueness % | Placeholder-filtered entities | Placeholder-filtered values | Placeholder-filtered duplicated values | Placeholder-filtered affected entities | Placeholder-filtered entity uniqueness %
# -----------+----------+-----------------------+---------------------+-------------------------------+-------------------------------+----------------------------------+-------------------------------+-----------------------------+---------------------------------------+--------------------------------------+------------------------------------------
# CFR	P12	188,177	185,297	3	2,883	98.468	185,298	185,296	2	4	99.998
# IMO	P49	30,529	1,136	2	29,395	3.715	1,136	1,135	1	2	99.824
# UVI	P14	3,868	3,866	2	4	99.897	3,868	3,866	2	4	99.897
# MMSI	P15	20,309	20,290	19	38	99.813	20,309	20,290	19	38	99.813
# Registration number	P10	183,401	153,589	7,219	37,031	79.809	183,401	153,589	7,219	37,031	79.809
# External marking	P9	185,617	173,442	8,769	20,944	88.717	185,617	173,442	8,769	20,944	88.717
#
# CSV exported: identifier_uniqueness.csv

# %% [markdown]
# # Broken Wikibase item link validation

# %%
# First retrieve only WikibaseItem properties.
query = """
PREFIX wikibase: <http://wikiba.se/ontology#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?propId ?propertyLabel
WHERE {
  # ?property a wikibase:Property ;
            wikibase:statementProperty ?statementProp ;
            wikibase:propertyType wikibase:WikibaseItem .

  OPTIONAL {
    # ?property rdfs:label ?propertyLabel .
    FILTER(LANG(?propertyLabel) = "en")
  }

  BIND(REPLACE(STR(?property), "^.*/entity/", "") AS ?propId)
}
ORDER BY ?propId
"""

results = run_query(query)

wikibase_item_properties = []

for b in results["results"]["bindings"]:
    prop_id = b["propId"]["value"]
    prop_label = b.get("propertyLabel", {}).get("value", prop_id)
    wikibase_item_properties.append((prop_id, prop_label))

print(f"WikibaseItem properties found: {len(wikibase_item_properties):,}")

rows = []
total_item_links = 0
total_broken_links = 0

for idx, (prop_id, prop_label) in enumerate(wikibase_item_properties, start=1):
    print(f"[{idx}/{len(wikibase_item_properties)}] {prop_id} {prop_label}")

    query = f"""
PREFIX p: <https://{ENDPOINT}.wikibase.cloud/prop/>
PREFIX ps: <https://{ENDPOINT}.wikibase.cloud/prop/statement/>
PREFIX wikibase: <http://wikiba.se/ontology#>

SELECT ?totalItemLinks ?brokenItemLinks
WHERE {{
  {{
    SELECT (COUNT(?value) AS ?totalItemLinks)
    WHERE {{
      # ?entity p:{prop_id} ?statement .
      # ?statement ps:{prop_id} ?value .
    }}
  }}

  {{
    SELECT (COUNT(?value) AS ?brokenItemLinks)
    WHERE {{
      # ?entity p:{prop_id} ?statement .
      # ?statement ps:{prop_id} ?value .

      FILTER NOT EXISTS {{
        # ?value wikibase:statements ?nStatements .
      }}
    }}
  }}
}}
    """

    try:
        res = run_query_timeout(query)
        b = res["results"]["bindings"][0]

        total = int(b["totalItemLinks"]["value"])
        broken = int(b["brokenItemLinks"]["value"])
        percent = (broken / total * 100) if total else 0

        if total > 0:
            rows.append((prop_id, prop_label, total, broken, percent))
            total_item_links += total
            total_broken_links += broken

        print(f"  -> total={total:,}; broken={broken:,}; broken%={percent:.3f}")

    except Exception as e:
        print(f"  -> ERROR: {e}")
        rows.append((prop_id, prop_label, "", "", ""))

    time.sleep(0.5)

rows_valid = [r for r in rows if r[2] != ""]
rows_valid.sort(key=lambda x: x[3], reverse=True)

print("\n=== BROKEN WIKIBASE ITEM LINKS ===\n")
print("Property | Label | Item links | Broken links | % broken")
print("---------+-------+------------+--------------+---------")

for prop_id, prop_label, total, broken, percent in rows_valid:
    print(f"{prop_id}\t{prop_label}\t{total:,}\t{broken:,}\t{percent:.3f}")

print(f"\nTOTAL ITEM LINKS: {total_item_links:,}")
print(f"TOTAL BROKEN LINKS: {total_broken_links:,}")
print(
    f"OVERALL BROKEN LINK RATE: "
    f"{(total_broken_links / total_item_links * 100 if total_item_links else 0):.3f}%"
)

with open(output_path("broken_wikibase_item_links.csv"), "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.writer(f, delimiter=";")
    writer.writerow([
        "Property",
        "PropertyLabel",
        "TotalItemLinks",
        "BrokenItemLinks",
        "PercentBroken"
    ])
    writer.writerows(rows_valid)
    writer.writerow([])
    writer.writerow([
        "TOTAL",
        "",
        total_item_links,
        total_broken_links,
        (total_broken_links / total_item_links * 100 if total_item_links else 0)
    ])

print("\nCSV exported: broken_wikibase_item_links.csv")
# Out:
# WikibaseItem properties found: 18
# [1/18] P11 registration place
#   -> total=124,760; broken=0; broken%=0.000
# [2/18] P18 has parent category
#   -> total=107; broken=0; broken%=0.000
# [3/18] P25 has fishing gear category
#   -> total=371,013; broken=0; broken%=0.000
# [4/18] P27 hull material
#   -> total=175,595; broken=0; broken%=0.000
# [5/18] P28 on board equipment
#   -> total=115,614; broken=0; broken%=0.000
# [6/18] P3 belongs to administrative unit
#   -> total=430; broken=0; broken%=0.000
# [7/18] P35 instance of
#   -> total=190,592; broken=0; broken%=0.000
# [8/18] P36 division of
#   -> total=92; broken=0; broken%=0.000
# [9/18] P38 subarea of
#   -> total=21; broken=0; broken%=0.000
# [10/18] P39 has divisions
#   -> total=92; broken=0; broken%=0.000
# [11/18] P40 has subareas
#   -> total=19; broken=0; broken%=0.000
# [12/18] P41 operates at
#   -> total=23,829; broken=0; broken%=0.000
# [13/18] P43 contains administrative unit
#   -> total=136; broken=0; broken%=0.000
# [14/18] P50 category of
#   -> total=4; broken=0; broken%=0.000
# [15/18] P51 has vessel category
#   -> total=187,575; broken=0; broken%=0.000
# [16/18] P52 subclass of
#   -> total=13; broken=0; broken%=0.000
# [17/18] P54 superseded by
#   -> total=3; broken=0; broken%=0.000
# [18/18] P7 has ports
#   -> total=295; broken=0; broken%=0.000
#
# === BROKEN WIKIBASE ITEM LINKS ===
#
# Property | Label | Item links | Broken links | % broken
# ---------+-------+------------+--------------+---------
# P11	registration place	124,760	0	0.000
# P18	has parent category	107	0	0.000
# P25	has fishing gear category	371,013	0	0.000
# P27	hull material	175,595	0	0.000
# P28	on board equipment	115,614	0	0.000
# P3	belongs to administrative unit	430	0	0.000
# P35	instance of	190,592	0	0.000
# P36	division of	92	0	0.000
# P38	subarea of	21	0	0.000
# P39	has divisions	92	0	0.000
# P40	has subareas	19	0	0.000
# P41	operates at	23,829	0	0.000
# P43	contains administrative unit	136	0	0.000
# P50	category of	4	0	0.000
# P51	has vessel category	187,575	0	0.000
# P52	subclass of	13	0	0.000
# P54	superseded by	3	0	0.000
# P7	has ports	295	0	0.000
#
# TOTAL ITEM LINKS: 1,190,190
# TOTAL BROKEN LINKS: 0
# OVERALL BROKEN LINK RATE: 0.000%
#
# CSV exported: broken_wikibase_item_links.csv

# %% [markdown]
# # Domain plausibility validation

# %%
PLAUSIBILITY_CHECKS = [
    (
        "LOA greater than zero",
        f"""
        PREFIX wdt: <https://{ENDPOINT}.wikibase.cloud/prop/direct/>
        SELECT (COUNT(?vessel) AS ?total) (SUM(IF(?loa <= 0, 1, 0)) AS ?anomalies)
        WHERE {{
          # ?vessel wdt:P16 ?loa .
        }}
        """
    ),
    (
        "GT tonnage non-negative",
        f"""
        PREFIX wdt: <https://{ENDPOINT}.wikibase.cloud/prop/direct/>
        SELECT (COUNT(?vessel) AS ?total) (SUM(IF(?gt < 0, 1, 0)) AS ?anomalies)
        WHERE {{
          # ?vessel wdt:P20 ?gt .
        }}
        """
    ),
    (
        "Main engine power greater than 0",
        f"""
        PREFIX wdt: <https://{ENDPOINT}.wikibase.cloud/prop/direct/>
        SELECT (COUNT(?vessel) AS ?total) (SUM(IF(?power < 0, 1, 0)) AS ?anomalies)
        WHERE {{
          # ?vessel wdt:P23 ?power .
        }}
        """
    ),
    (
        "Construction date not after entry into service",
        f"""
        PREFIX wdt: <https://{ENDPOINT}.wikibase.cloud/prop/direct/>
        SELECT (COUNT(?vessel) AS ?total)
               (SUM(IF(?constructionDate > ?entryDate, 1, 0)) AS ?anomalies)
        WHERE {{
          # ?vessel wdt:P30 ?constructionDate ;
                  wdt:P29 ?entryDate .
        }}
        """
    ),
    (
        "Retirement date not before entry into service",
        f"""
        PREFIX wdt: <https://{ENDPOINT}.wikibase.cloud/prop/direct/>
        SELECT (COUNT(?vessel) AS ?total)
               (SUM(IF(?retirementDate < ?entryDate, 1, 0)) AS ?anomalies)
        WHERE {{
          # ?vessel wdt:P29 ?entryDate ;
                  wdt:P58 ?retirementDate .
        }}
        """
    ),
    (
        "Destruction date not before construction",
        f"""
        PREFIX wdt: <https://{ENDPOINT}.wikibase.cloud/prop/direct/>
        SELECT (COUNT(?vessel) AS ?total)
               (SUM(IF(?destructionDate < ?constructionDate, 1, 0)) AS ?anomalies)
        WHERE {{
          # ?vessel wdt:P30 ?constructionDate ;
                  wdt:P57 ?destructionDate .
        }}
        """
    ),
]

rows = []
total_checked = 0
total_anomalies = 0

for check_label, query in PLAUSIBILITY_CHECKS:
    try:
        results = run_query(query)
        b = results["results"]["bindings"][0]

        total = int(b["total"]["value"])
        anomalies = int(b["anomalies"]["value"]) if "anomalies" in b else 0
        valid = total - anomalies

        percent_valid = (valid / total * 100) if total else 0
        percent_anomalous = (anomalies / total * 100) if total else 0

        rows.append((
            check_label,
            total,
            valid,
            anomalies,
            percent_valid,
            percent_anomalous,
        ))

        total_checked += total
        total_anomalies += anomalies

    except Exception as e:
        print(f"Error with {check_label}: {e}")
        rows.append((check_label, "", "", "", "", ""))

overall_valid = total_checked - total_anomalies
overall_percent_valid = (overall_valid / total_checked * 100) if total_checked else 0
overall_percent_anomalous = (total_anomalies / total_checked * 100) if total_checked else 0

print("\n=== DOMAIN PLAUSIBILITY VALIDATION ===\n")
print("Check | Total checked | Valid | Anomalies | % valid | % anomalous")
print("------+---------------+-------+-----------+---------+------------")

for check_label, total, valid, anomalies, percent_valid, percent_anomalous in rows:
    if total == "":
        print(f"{check_label}\tERROR")
    else:
        print(
            f"{check_label}\t"
            f"{total:,}\t"
            f"{valid:,}\t"
            f"{anomalies:,}\t"
            f"{percent_valid:.3f}\t"
            f"{percent_anomalous:.3f}"
        )

print(f"\nTOTAL VALUES CHECKED: {total_checked:,}")
print(f"TOTAL VALID VALUES: {overall_valid:,}")
print(f"TOTAL DOMAIN ANOMALIES: {total_anomalies:,}")
print(f"OVERALL DOMAIN PLAUSIBILITY: {overall_percent_valid:.3f}%")
print(f"OVERALL DOMAIN ANOMALY RATE: {overall_percent_anomalous:.3f}%")

with open(output_path("domain_plausibility_validation.csv"), "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.writer(f, delimiter=";")
    writer.writerow([
        "Check",
        "TotalChecked",
        "Valid",
        "DetectedAnomalies",
        "PercentValid",
        "PercentAnomalous"
    ])
    writer.writerows(rows)
    writer.writerow([])
    writer.writerow([
        "TOTAL",
        total_checked,
        overall_valid,
        total_anomalies,
        overall_percent_valid,
        overall_percent_anomalous
    ])

print("\nCSV exported: domain_plausibility_validation.csv")
# Out:
# === DOMAIN PLAUSIBILITY VALIDATION ===
#
# Check | Total checked | Valid | Anomalies | % valid | % anomalous
# ------+---------------+-------+-----------+---------+------------
# LOA greater than zero	181,359	181,359	0	100.000	0.000
# GT tonnage non-negative	153,629	153,629	0	100.000	0.000
# Main engine power greater than 0	210,112	210,112	0	100.000	0.000
# Construction date not after entry into service	161,022	160,937	85	99.947	0.053
# Retirement date not before entry into service	70,535	70,417	118	99.833	0.167
# Destruction date not before construction	32,642	32,642	0	100.000	0.000
#
# TOTAL VALUES CHECKED: 809,299
# TOTAL VALID VALUES: 809,096
# TOTAL DOMAIN ANOMALIES: 203
# OVERALL DOMAIN PLAUSIBILITY: 99.975%
# OVERALL DOMAIN ANOMALY RATE: 0.025%
#
# CSV exported: domain_plausibility_validation.csv

# %% [markdown]
# # Geospatial validation

# %%
query = f"""
PREFIX wdt: <https://{ENDPOINT}.wikibase.cloud/prop/direct/>

SELECT ?portId ?coord
WHERE {{
  # ?port wdt:P42 ?coord .
  BIND(REPLACE(STR(?port), "^.*/entity/", "") AS ?portId)
}}
"""

results = run_query(query)

rows = []
invalid_rows = []

for b in results["results"]["bindings"]:
    port_id = b["portId"]["value"]
    coord = b["coord"]["value"]

    clean = coord.replace("Point(", "").replace(")", "")
    lon, lat = clean.split(" ")

    lon = float(lon)
    lat = float(lat)

    is_valid = -180 <= lon <= 180 and -90 <= lat <= 90

    rows.append((port_id, lon, lat, is_valid))

    if not is_valid:
        invalid_rows.append((port_id, lon, lat))

total_ports_with_coordinates = len(rows)
invalid_coordinates = len(invalid_rows)
valid_coordinates = total_ports_with_coordinates - invalid_coordinates
percent_valid_coordinates = (
    valid_coordinates / total_ports_with_coordinates * 100
    if total_ports_with_coordinates else 0
)

print("\n=== GEOSPATIAL VALIDATION ===\n")
print(f"PORTS WITH COORDINATES: {total_ports_with_coordinates:,}")
print(f"VALID COORDINATES: {valid_coordinates:,}")
print(f"INVALID COORDINATES: {invalid_coordinates:,}")
print(f"PERCENT VALID COORDINATES: {percent_valid_coordinates:.3f}")

with open(output_path("geospatial_validation.csv"), "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.writer(f, delimiter=";")
    writer.writerow([
        "PortsWithCoordinates",
        "ValidCoordinates",
        "InvalidCoordinates",
        "PercentValidCoordinates"
    ])
    writer.writerow([
        total_ports_with_coordinates,
        valid_coordinates,
        invalid_coordinates,
        percent_valid_coordinates
    ])

with open(output_path("invalid_port_coordinates.csv"), "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.writer(f, delimiter=";")
    writer.writerow(["Port", "Longitude", "Latitude"])
    writer.writerows(invalid_rows)

print("\nCSV exported: geospatial_validation.csv")
print("CSV exported: invalid_port_coordinates.csv")
# Out:
# === GEOSPATIAL VALIDATION ===
#
# PORTS WITH COORDINATES: 1,927
# VALID COORDINATES: 1,927
# INVALID COORDINATES: 0
# PERCENT VALID COORDINATES: 100.000
#
# CSV exported: geospatial_validation.csv
# CSV exported: invalid_port_coordinates.csv
